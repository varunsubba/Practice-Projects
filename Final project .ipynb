# %% [markdown]
# ## Use food().customer_register()--- to register yourself
# ## Use food().customer_login()--- to login after register
# ## Admin pre defiend id-admin and pass- admin@123
# ## Admin full control

# %%
item_list={}
customer_detail={}

# %%
import random
import string
class food:
    def __init__(self):
        self.login=False
    def customer_register(self):
        self.customer_name=(input("Enter your Full name to register : ")).capitalize()
        a=int(input("Enter your phone number here , 10 digit number only : "))
        if len(str(a))==10:
            self.customer_number=a
        else:
            print("\n Your mobile number does not contains 10 digits ")
            self.customer_number=int(input("Enter your phone number here , 10 digit number only : "))
        self.customer_email=input("Enter you email here : ")
        self.customer_password=input("Create your password")
        s={}
        s["customer_name"]=self.customer_name
        s["customer_password"]=self.customer_password
        s["customer_eamil"]=self.customer_email
        customer_detail[self.customer_number]=s
        
        print("\n Your registration process is completed sucessfully ")
        
    def customer_login(self):
        number=int(input("Enter you register number here : "))
        if number in customer_detail:
            pas=input("Enter you password here : ")
            if customer_detail[number]["customer_password"]==pas:
                order_history=[]
                print("\n Login sucessfull \n")
                print("Welcome",(customer_detail[number]["customer_name"]).capitalize())
                print(end=" \n")
                print(f" 1.Place a new order \n\n 2.Order history \n\n 3.Update profile \n\n 4.Exit")
                while True: # Placeing new oders here 
                    customer_select=int(input(""))
                    if customer_select==1:
                        print("\033[1m Please choose the below item available : \n")
                        for j,i in enumerate(item_list,start=1):
                            print("\033[0m"+str(j)+"."+" ".join(map(str, item_list[str(i)]))+"\n")
                        print("Choose the above item to add into cart")
                        sort=list(enumerate(item_list))
                        bill_total=[] # appending the total amount in the list so that I can sum it to show the total amount
                        item_selected=[]
                        j=input()
                        n=j.split(",") # splititng and making into int so that ,can specific the item customer want to order.
                        for i in n:
                            a=sort[int(i)-1][1]
                            price=item_list[a][2]
                            bill_total.append(price)
                            item_selected.append(item_list[a][0])
                            item_selected.append(item_list[a][2])
                            print(a+"-->",item_list[a][0],"=",item_list[a][2])
                        print("\033[1m Total = ","\033[0m",sum(bill_total))
                        buy=input(f"Do you want to purchase it (Y) or (N) : ").capitalize()
                        if buy=="Y":
                            order_history.append(item_selected)
                            print("Order is completed")
                            print("Thanks for ordering")
                            print(end="\n")
                            print(f" 1.Place a new order   2.Order history   3.Update profile  4.Exit")
                        else:
                            print("Come back soon")
                            print(end="\n")
                            print(f" 1.Place a new order   2.Order history   3.Update profile  4.Exit")
                            
                    elif customer_select==2:
                        for j,i in enumerate(order_history,start=1):
                            print(str(j)+". "+"".join(str(i)))
                        print(f"1.Place a new order  2.Order history  3.Update profile  4.Exit ")
                    elif customer_select==3:# Customer can update their info using their phone number as a key.
                        if number in customer_detail:
                            while True:
                                print("\033[0m 1.Change name  2. Update email  3. Change password    4.Exit")
                                edit_customer=int(input())
                                if edit_customer==1:
                                    customer_detail[number]["customer_name"]=input("Enter the new name here : ").capitalize()
                                elif edit_customer==2:
                                    customer_detail[number]["customer_eamil"]=input("Enter the new email here : ")
                                elif edit_customer==3:
                                    customer_detail[number]["customer_password"]=input("Enter the new password here : ")
                                elif edit_customer==4:
                                    print("Done")
                                    print(end="\n")
                                    print(f"1.Place a new order  2.Order history  3.Update profile  4.Exit ")
                                    break
                                else:
                                    print("Choose the correct option!")
                        else:
                            print("Customer not found!") # update the profile here 
                    elif customer_select==4:
                        print("Come back soon !")
                        break
                    else:
                        print(f"\033[1m Try again!! \033[0m Choose the above option")
                    
                
            else:
                print("Password is wrong !")
        else:
            print("No user found!") # Place New Order Order History Update Profile
            
 # below the adim control id-admin pass- admin@123 for the pre set password for admin     
    def admin_login(self):
        a_n=input("Enter the user name : ")
        admin_name=a_n.upper()
        if admin_name=="ADMIN":
            admin_pass=input("Enter the password : ")
            if admin_pass=="admin@123":
                print("login successfull!")
                print(end="\n")
                print("Welcome Admin")
                print(end="\n")
                print(f" 1.Add item \n\n 2.Edit food items \n\n 3.View the list of all food items \n\n 4.Remove a food item \n\n 5.Discount item \n\n 6.Exit")
                while True:
                    admin_select=int(input("")) # Adding the item by adim control
                    if admin_select==1:
                        item=[]
                        product_id="".join(random.choices(string.ascii_uppercase+string.digits,k=3))
                        n=input("Enter the Food item  of the item : ")
                        item.append(n.upper())
                        q=input("Enter the quantity, For eg, 100ml, 250gm, 4pieces : ")
                        item.append(q.upper())
                        p=int(input("Enter the price of the item added : "))
                        item.append(p)
                        item_list[product_id]=item
                        print("Item is addeded successfully!")
                        print(end="\n")
                        print(f"1.Add item   2.Edit food items   3.View the list of all food items   4.Remove a food item   5.Discount item    6.Exit ")
                    elif admin_select==2: # Editing the pre added food item by adim control
                        input_id=input("Enter the product Id of the product you want to edit : ").upper()
                        if input_id in item_list:
                            while True:
                                print("\033[0m 1.Change the product name  2. Change the product quantity  3. Change the price of the product    4.Exit")
                                edit=int(input())
                                if edit==1:
                                    item_list[input_id][0]=input("Enter the new item name here : ").upper()
                                    print("Name is updated successfully")
                                elif edit==2:
                                    item_list[input_id][1]=str(input("Enter the new quantity for the item here : ")).upper()
                                    print("Quantity it updated succesfully")
                                elif edit==3:
                                    item_list[input_id][2]=int(input("Enter the new price for the item here : "))
                                    print("Price is updated successfully ")
                                elif edit==4:
                                    print("Done")
                                    print(end="\n")
                                    print(f"1.Add item   2.Edit food items   3.View the list of all food items   4.Remove a food item    5.Exit ")
                                    break

                                else:
                                    print("\033[1m Choose the correct option")


                        else:
                            print("Item not found ! ")
                            print(end="\n")
                            print(f"1.Add item   2.Edit food items   3.View the list of all food items   4.Remove a food item   5.Discount item    6.Exit ")
                    elif admin_select==3: # Showing the all added item with their respective auto generated Id
                        print("\033[1m Here is the list of all items:\n")
                        for j,i in enumerate(item_list,start=1):
                            print("\033[0m"+str(j)+".",i,"-->"," ".join(map(str, item_list[str(i)])))
                            print(end="\n")
                        print(f"1.Add item   2.Edit food items   3.View the list of all food items   4.Remove a food item   5.Discount item    6.Exit ")
                    elif admin_select==4: # Removing the food item from the added list using food id generated by admin control
                        id_remove=input("Enter the Product Id for the item you want to remove")
                        if id_remove in item_list:
                            del item_list[id_remove]
                            print("Item is removed successfully!")
                            print(end="\n")
                            print(f"1.Add item   2.Edit food items   3.View the list of all food items   4.Remove a food item   5.Discount item    6.Exit ")
                        else:
                            print(f"Their is no item with Product Id--{id_remove}")
                            print(end="\n")
                            print(f"1.Add item   2.Edit food items   3.View the list of all food items   4.Remove a food item   5.Discount item    6.Exit ")
                    elif admin_select==5:
                        p_id=input("Enter the product Id to appyly the discount : ")
                        if p_id in item_list:
                            discount_persentage=int(input(f"Enter the discount percentage you want to apply in {item_list[p_id][1]} : "))
                            discount_price=(discount_persentage/100)*item_list[p_id][2]
                            new_price=item_list[p_id][2]-discount_price
                            item_list[p_id][2]=new_price
                            print(f"Item name {item_list[p_id][0]} price is {discount_persentage}% discounted and new price is {new_price}.")
                        else:
                            print("Item not found")
                            print(end="\n")
                            print(f"1.Add item   2.Edit food items   3.View the list of all food items   4.Remove a food item   5.Discount item    6.Exit ")
                    elif admin_select==6:
                        print("Come back soon !")
                        break
                    else:
                        print(f"\033[1m Try again!! \033[0m Choose the above option")
            else:
                print("Password is wrong !")
        else:
            print("Admin not found !")
